# %% [markdown]
# <a href="https://colab.research.google.com/github/Infant-Joshva/AI_Agents-Learning_Materials/blob/main/Practical_Part/LangChain_RAG_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG from Youtube Transcript using LangChain

# %% [markdown]
# ## Installing the Library

# %%
import os
from getpass import getpass
os.environ["GEMINI_API_KEY"] = getpass('Enter your API Key:')
# Out:
# Enter your API Key:··········

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-google-genai faiss-cpu

# %%
from IPython.terminal.embed import EmbeddedMagics
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ## Indexing (Document Injection)

# %%
video_id = "AMZSCWxOU9M"

try:
    api = YouTubeTranscriptApi()   # create object
    transcript_list = api.fetch(video_id, languages=['en-IN'])

    transcript = " ".join([chunk.text for chunk in transcript_list])
    print (transcript)
except TranscriptsDisabled:
    print("No captions available for this video.... ⚠️")
# Out:
# [Intro music plays] Hello, everyone!
# I’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major
# recent discovery. A three-day conference
# was recently held. Scientists and
# archaeologists from Switzerland and
# France participated. They presented evidence
# of Tamil presence. Not many people are
# aware of this breakthrough. Tamil names were discovered
# in Egypt's Valley of the Kings. This is the sacred burial
# site of Egyptian Pharaohs. Great kings were buried there
# with gold and precious gems. Tamil names were
# found in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this
# video will give you goosebumps. We often discuss
# globalization today. We talk about international
# trade and connectivity. We also discuss
# issues that arise when leaders like
# Trump come to power. But 2,000 years ago, Tamils were already practicing
# globalization. Today, we have actual
# proof, not just literature. It shows how advanced
# Tamil society was. When we say 2,000 years ago, we may imagine a primitive life. But that is not true. Tamils travelled from
# Tamil Nadu to Egypt, not just to nearby regions. It is significant to find
# their names in the pyramids. I will share the
# details with you today. I'll explain its age
# and why it matters. I will explain how
# it was discovered and why the
# location is significant. Subscribe to stay updated
# on world events and history. Follow us for daily updates
# on current and ancient news. Make sure to subscribe. It ensures you never
# miss our latest videos. We cover major discoveries
# alongside global events. Join us to stay informed. Now, let's look at
# what was discovered. We must credit the
# Tamil Nadu government. They played a vital
# role in this research. The government organized
# the Tamil Epigraphy Conference. It was held in Chennai
# from February 11th to 14th. The focus was on ancient
# Tamil scripts and research. Experts from China, Africa, Europe, and America attended. These are world-renowned
# scholars of the Tamil language. They study archaeological
# sites worldwide. This conference united experts
# researching Tamil inscriptions. Professor Ingo and Professor
# Charlotte presented their findings. They produced a
# detailed research paper. They identified 30 inscriptions
# inside royal tombs in Egypt. These are located in
# the Valley of the Kings. The Valley of the
# Kings is in Egypt. It dates back
# thousands of years, long before the era of Jesus. The pyramids were built as royal
# burial sites around 5,000 years ago. Kings were mummified and
# buried with immense wealth. These remains were
# preserved for five millennia. Bodies were kept in golden
# caskets inside the pyramids. This tradition
# continued for centuries. However, later dynasties
# faced issues with tomb raiding. Thieves would break into
# pyramids to steal the gold. Theft was a major
# problem even then. Thefts occurred when unguarded, or even security guards
# stole the treasures. The kings were long gone. The pyramids were
# built on religious beliefs. But just like today,
# temples were often targeted. Egypt is covered by
# vast desert mountains. They began carving tombs
# into mountains to hide the kings. They shifted from
# pyramids to prevent theft. Hiding the tombs made
# them harder to find. They believed kings needed
# this wealth for the afterlife. This took place in a
# region called Luxor. Luxor is 600 kilometers
# inland from the Egyptian coast. That's like the distance
# from Kanyakumari to Chennai. Even today, that's a
# twelve-hour journey. Imagine the effort back then. They carved mountains in
# the desert to remain hidden. One wouldn't expect such
# treasure in a remote mountain. Yet, that is where
# they were buried. Many famous kings rest there. The mummies of Tutankhamun
# and Seti were found here. It was a secure location. About 2,000 years ago,
# during Cleopatra's era, Roman rule began in Egypt. This was the age of
# Cleopatra's legendary beauty. It was when Julius
# Caesar conquered Egypt. The era of Mark
# Antony and Cleopatra. This was a thousand years
# before Tanjore Temple was built. It was roughly during
# the time of Jesus. Inscriptions from this era
# reveal Tamil names in pyramids. Let's look at the
# professors' presentation. The name “Sikai Kotran” appears
# nine times across five tombs. This is highly significant. There are also many
# other Tamil names. Names like Koppan, Kiran,
# and Kattan were also identified. Words like "Vandhaan" and
# "Kandaan" accompany them. It essentially means
# "Sikai Kotran visited here." These names were common in
# Tamil society 2,000 years ago. They might have been
# warriors or merchants. Most likely, they
# were merchants. Sanskrit and Prakrit
# names were also identified. However, Tamil names
# are the most frequent. They appear in
# much higher numbers. There is also the
# Temple of Isis, dedicated to an ancient
# Egyptian goddess. Tamil names are present
# even in that sacred site. Pottery shards from 2,300
# years ago also bear Tamil names. Let me explain the
# significance of this. What does finding
# these names mean? It confirms a few
# important things. First, Tamil mobility
# was highly organized. Sikai Kotran traveled
# an incredible distance. There were no planes or
# modern technology then. They likely crossed
# the Indian Ocean, passed the Red Sea, and
# reached Egypt via the Nile. This happened under
# Roman administration. There was mutual
# cooperation between Tamils, Romans, and Egyptians. Travel was only possible
# through these relations. While modern leaders
# debate trade barriers, Tamils were trading freely
# in Roman-controlled Egypt. Second, these merchants
# had significant wealth. The Valley of the Kings
# is far from the coastline. Basic traders would
# usually stay near the ports. Only the very wealthy
# explore a country's interior. Most people today
# travel only for work. But those who are
# well-off explore as tourists. Traveling 600 kilometers inland required resources
# and protection. They likely had bodyguards
# for safety in a foreign land. If they journeyed like explorers and left their names behind, it shows they had
# substantial financial strength. They were wealthy enough
# to visit Egypt as explorers. Third, the Tamil
# script was widely used. It wasn't just for
# scholars and poets. Business people and
# travelers were also literate. They wrote their names with
# the intent that they would endure. This shows Tamil was widely
# understood and actively used. Fourth, they were proud
# of their identity as Tamils. Often, people abroad
# hesitate to reveal their identity. For example, in a film, a hero hides
# his Indian identity in Pakistan. Political tensions raise
# identity safety concerns. But then, Tamil regions,
# Egypt, and Rome had stable ties. Egypt was under Roman rule,
# similar to later colonial times. At that time, it was the Tamil
# region, not modern India. Tamils maintained strong relations
# with Romans and Egyptians. Fifth, Indo-Roman trade
# was human, not just material. Roman coins were found in
# Adichanallur, Keezhadi, and Korkai. That proved Romans and
# Greeks came to Tamil Nadu. Finding Tamil names in Egypt
# proves Tamils also traveled there. Both sides travelled
# to each other’s lands. Ancient Tamil hubs were like
# modern global trade centers. Despite limited transport,
# mobility and trade were strong. This shows Tamil Nadu was
# highly advanced in that era. Sixth, South India
# was integrated into the Roman
# cosmopolitan world. A massive cultural exchange
# existed between these regions. People traveled,
# settled, and shared ideas. Seventh, Tamil presence
# wasn't limited to ports. They didn't just stay
# at the water's edge. Traveling 600 kilometers inland
# suggests deeper settlement. Tamils likely lived
# along those routes. Tamil identity
# was visible there. This implies
# broader integration. Eighth, they were driven
# by religious curiosity. Why would Sikai Kotran
# want to see these tombs? If I visit London, I make
# it a point to see Scotland. I want to see the scenery
# and historical landmarks. I visit sites like Waterloo
# out of historical interest. Such journeys reflect
# curiosity about art and heritage. Sikai Kotran traveled 600 kilometers
# out of that same curiosity. They wanted to learn how
# the Pharaohs were buried. It's rare for one culture to
# explore another so deeply. Usually, traders just
# focus on the business. But these Tamils were
# true global explorers. Kiran, Kotran, and Koppan
# were pioneers of their time. They ventured out
# to see the world. It's a fascinating history. Ninth, in the Sangam era, Tamils were not
# isolated from the world. They were part of a
# globalized community. They practiced
# early globalization. Trade, diplomacy, and exchange
# were active 2,000 years ago. People traveled, learned,
# and shared culture. They brought global culture
# home and shared theirs abroad. They lived proudly with
# identity, without fear. This knowledge is
# incredibly valuable. I wanted to share
# this story with you. It might seem small, but finding these names
# is historically profound. That's the beauty
# of archaeology. One small finding can
# map out an entire era. I appreciate the government's
# effort in supporting this. We must acknowledge progress as we critique mistakes. Research must continue
# across all administrations. We need to keep
# uncovering the past. Development means
# research, not just preservation. We must actively seek
# out what is still hidden. That strengthens
# claims of Tamil antiquity. More evidence is needed to prove Tamil was
# the first language. It's great to see these
# findings coming to light. Share this with
# friends worldwide who are interested
# in Tamil history. Sikai Kotran was a
# pioneer of global travel. Share this video if
# you found it interesting. I will see you tomorrow. Love you all! Take care, bye! Cheers, MG's!

# %%
transcript_list
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='[Intro music plays]', start=0.073, duration=6.561), FetchedTranscriptSnippet(text='Hello, everyone!\nI’m Madan Gowri.', start=6.658, duration=1.5), FetchedTranscriptSnippet(text='Hello, my dear MG squad!', start=8.221, duration=1.567), FetchedTranscriptSnippet(text='Would you believe Tamil words', start=9.889, duration=2.833), FetchedTranscriptSnippet(text='were carved in Egypt’s pyramids?', start=12.746, duration=2.604), FetchedTranscriptSnippet(text='This is a major\nrecent discovery.', start=15.469, duration=4.041), FetchedTranscriptSnippet(text='A three-day conference\nwas recently held.', start=19.534, duration=2.774), FetchedTranscriptSnippet(text='Scientists and\narchaeologists from', start=22.572, duration=3.511), FetchedTranscriptSnippet(text='Switzerland and\nFrance participated.', start=26.107, duration=2.708), FetchedTranscriptSnippet(text='They presented evidence\nof Tamil presence.', start=28.839, duration=2.829), FetchedTranscriptSnippet(text='Not many people are\naware of this breakthrough.', start=31.823, duration=3.718), FetchedTranscriptSnippet(text="Tamil names were discovered\nin Egypt's Valley of the Kings.", start=35.605, duration=6.317), FetchedTranscriptSnippet(text='This is the sacred burial\nsite of Egyptian Pharaohs.', start=41.946, duration=8.332), FetchedTranscriptSnippet(text='Great kings were buried there\nwith gold and precious gems.', start=50.499, duration=4.049), FetchedTranscriptSnippet(text='Tamil names were\nfound in this very location.', start=54.572, duration=2.059), FetchedTranscriptSnippet(text='I will explain those names.', start=56.655, duration=0.961), FetchedTranscriptSnippet(text='But first, watch this.', start=57.64, duration=1.442), FetchedTranscriptSnippet(text='For Tamils worldwide, this\nvideo will give you goosebumps.', start=59.228, duration=14.24), FetchedTranscriptSnippet(text='We often discuss\nglobalization today.', start=73.545, duration=3.431), FetchedTranscriptSnippet(text='We talk about international\ntrade and connectivity.', start=77.0, duration=3.712), FetchedTranscriptSnippet(text='We also discuss\nissues that arise', start=80.736, duration=1.471), FetchedTranscriptSnippet(text='when leaders like\nTrump come to power.', start=82.231, duration=1.807), FetchedTranscriptSnippet(text='But 2,000 years ago, Tamils were', start=84.175, duration=4.225), FetchedTranscriptSnippet(text='already practicing\nglobalization.', start=88.424, duration=5.453), FetchedTranscriptSnippet(text='Today, we have actual\nproof, not just literature.', start=93.901, duration=7.29), FetchedTranscriptSnippet(text='It shows how advanced\nTamil society was.', start=101.215, duration=1.774), FetchedTranscriptSnippet(text='When we say 2,000 years ago,', start=103.013, duration=1.768), FetchedTranscriptSnippet(text='we may imagine a primitive life.', start=104.805, duration=4.296), FetchedTranscriptSnippet(text='But that is not true.', start=109.125, duration=1.428), FetchedTranscriptSnippet(text='Tamils travelled from\nTamil Nadu to Egypt,', start=110.578, duration=2.943), FetchedTranscriptSnippet(text='not just to nearby regions.', start=113.545, duration=3.208), FetchedTranscriptSnippet(text='It is significant to find\ntheir names in the pyramids.', start=116.782, duration=4.766), FetchedTranscriptSnippet(text='I will share the\ndetails with you today.', start=121.572, duration=1.785), FetchedTranscriptSnippet(text="I'll explain its age\nand why it matters.", start=123.381, duration=3.331), FetchedTranscriptSnippet(text='I will explain how\nit was discovered', start=126.736, duration=1.536), FetchedTranscriptSnippet(text='and why the\nlocation is significant.', start=128.296, duration=3.503), FetchedTranscriptSnippet(text='Subscribe to stay updated\non world events and history.', start=131.823, duration=5.36), FetchedTranscriptSnippet(text='Follow us for daily updates\non current and ancient news.', start=137.319, duration=4.952), Fet ...

# %% [markdown]
# ## Text Splitting

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %%
chunks
# Out:
# [Document(metadata={}, page_content="[Intro music plays] Hello, everyone!\nI’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major\nrecent discovery. A three-day conference\nwas recently held. Scientists and\narchaeologists from Switzerland and\nFrance participated. They presented evidence\nof Tamil presence. Not many people are\naware of this breakthrough. Tamil names were discovered\nin Egypt's Valley of the Kings. This is the sacred burial\nsite of Egyptian Pharaohs. Great kings were buried there\nwith gold and precious gems. Tamil names were\nfound in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this\nvideo will give you goosebumps. We often discuss\nglobalization today. We talk about international\ntrade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual"),
#  Document(metadata={}, page_content="trade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual\nproof, not just literature. It shows how advanced\nTamil society was. When we say 2,000 years ago, we may imagine a primitive life. But that is not true. Tamils travelled from\nTamil Nadu to Egypt, not just to nearby regions. It is significant to find\ntheir names in the pyramids. I will share the\ndetails with you today. I'll explain its age\nand why it matters. I will explain how\nit was discovered and why the\nlocation is significant. Subscribe to stay updated\non world events and history. Follow us for daily updates\non current and ancient news. Make sure to subscribe. It ensures you never\nmiss our latest videos. We cover major discoveries\nalongside global events. Join us to stay informed. Now, let's look at\nwhat was discovered. We must credit the\nTamil Nadu government. They played a vital"),
#  Document(metadata={}, page_content="alongside global events. Join us to stay informed. Now, let's look at\nwhat was discovered. We must credit the\nTamil Nadu government. They played a vital\nrole in this research. The government organized\nthe Tamil Epigraphy Conference. It was held in Chennai\nfrom February 11th to 14th. The focus was on ancient\nTamil scripts and research. Experts from China, Africa, Europe, and America attended. These are world-renowned\nscholars of the Tamil language. They study archaeological\nsites worldwide. This conference united experts\nresearching Tamil inscriptions. Professor Ingo and Professor\nCharlotte presented their findings. They produced a\ndetailed research paper. They identified 30 inscriptions\ninside royal tombs in Egypt. These are located in\nthe Valley of the Kings. The Valley of the\nKings is in Egypt. It dates back\nthousands of years, long before the era of Jesus. The pyramids were built as royal\nburial sites around 5,000 years ago. Kings were mummified and"),
#  Document(metadata={}, page_content='Kings is in Egypt. It dates back\nthousands of years, long before the era of Jesus. The pyramids were built as royal\nburial sites around 5,000 years ago. Kings were mummified and\nburied with immense wealth. These remains were\npreserved for five millennia. Bodies were kept in golden\ncaskets inside the pyramids. This tradition\ncontinued for centuries. However, later dynasties\nfaced issues with tomb raiding. Thieves would break into\npyramids to steal the gold. Theft was a major\nproblem even then. Thefts occurred when unguarded, or even security guards\nstole the treasures. The kings were long gone. The pyramids were\nbuilt on religious beliefs. But just like today,\ntemples were often targeted. Egypt is covered by\nvast desert mountains. They began carving tombs\ninto mountains to hide the kings. They shifted from\npyramids to prevent theft. Hiding the tombs made\nthem harder to find. They believed kings needed\nthis wealth for the afterlife. This took place in a'),
#  Document(metadata={}, page_content="pyramids to prevent theft. Hiding the tombs made\nthem harder to find. They believed kings needed\nthis wealth for the afterlife. This took place in a\nregion called Luxor. Luxor is 600 kilometers\ninland from the Egyptian coast. That's like the distance\nfrom Kanyakumari to Chennai. Even today, that's a\ntwelve-hour journey. Imagine the effort back then. They carved mountains in\nthe desert to remain hidden. One wouldn't expect such\ntreasure in a remote mountain. Yet, that is where\nthey were buried. Many famous kings rest there. The mummies of Tutankhamun\nand Seti were found here. It was a secure location. About 2,000 years ago,\nduring Cleopatra's era, Roman rule began in Egypt. This was the age of\nCleopatra's legendary beauty. It was when Julius\nCaesar conquered Egypt. The era of Mark\nAntony and Cleopatra. This was a thousand years\nbefore Tanjore Temple was built. It was roughly during\nthe time of Jesus. Inscriptions from this era\nreveal Tamil names in pyramids. Let's look at the"),
#  Document(metadata={}, page_content='Antony and Cleopatra. This was a thousand years\nbefore Tanjore Temple was built. It was roughly during\nthe time of Jesus. Inscriptions from this era\nreveal Tamil names in pyramids. Let\'s look at the\nprofessors\' presentation. The name “Sikai Kotran” appears\nnine times across five tombs. This is highly significant. There are also many\nother Tamil names. Names like Koppan, Kiran,\nand Kattan were also identified. Words like "Vandhaan" and\n"Kandaan" accompany them. It essentially means\n"Sikai Kotran visited here." These names were common in\nTamil society 2,000 years ago. They might have been\nwarriors or merchants. Most likely, they\nwere merchants. Sanskrit and Prakrit\nnames were also identified. However, Tamil names\nare the most frequent. They appear in\nmuch higher numbers. There is also the\nTemple of Isis, dedicated to an ancient\nEgyptian goddess. Tamil names are present\neven in that sacred site. Pottery shards from 2,300\nyears ago also bear Tamil names. Let me explain the'),
#  Document(metadata={}, page_content="Temple of Isis, dedicated to an ancient\nEgyptian goddess. Tamil names are present\neven in that sacred site. Pottery shards from 2,300\nyears ago also bear Tamil names. Let me explain the\nsignificance of this. What does finding\nthese names mean? It confirms a few\nimportant things. First, Tamil mobility\nwas highly organized. Sikai Kotran traveled\nan incredible distance. There were no planes or\nmodern technology then. They likely crossed\nthe Indian Ocean, passed the Red Sea, and\nreached Egypt via the Nile. This happened under\nRoman administration. There was mutual\ncooperation between Tamils, Romans, and Egyptians. Travel was only possible\nthrough these relations. While modern leaders\ndebate trade barriers, Tamils were trading freely\nin Roman-controlled Egypt. Second, these merchants\nhad significant wealth. The Valley of the Kings\nis far from the coastline. Basic traders would\nusually stay near the ports. Only the very wealthy\nexplore a country's interior. Most people today"),
#  Document(metadata={}, page_content="had significant wealth. The Valley of the Kings\nis far from the coastline. Basic traders would\nusually stay near the ports. Only the very wealthy\nexplore a country's interior. Most people today\ntravel only for work. But those who are\nwell-off explore as tourists. Traveling 600 kilometers inland required resources\nand protection. They likely had bodyguards\nfor safety in a foreign land. If they journeyed like explorers and left their names behind, it shows they had\nsubstantial financial strength. They were wealthy enough\nto visit Egypt as explorers. Third, the Tamil\nscript was widely used. It wasn't just for\nscholars and poets. Business people and\ntravelers were also literate. They wrote their names with\nthe intent that they would endure. This shows Tamil was widely\nunderstood and actively used. Fourth, they were proud\nof their identity as Tamils. Often, people abroad\nhesitate to reveal their identity. For example, in a film, a hero hides"),
#  Document(metadata={}, page_content='understood and actively used. Fourth, they were proud\nof their identity as Tamils. Often, people abroad\nhesitate to reveal their identity. For example, in a film, a hero hides\nhis Indian identity in Pakistan. Political tensions raise\nidentity safety concerns. But then, Tamil regions,\nEgypt, and Rome had stable ties. Egypt was under Roman rule,\nsimilar to later colonial times. At that time, it was the Tamil\nregion, not modern India. Tamils maintained strong relations\nwith Romans and Egyptians. Fifth, Indo-Roman trade\nwas human, not just material. Roman coins were found in\nAdichanallur, Keezhadi, and Korkai. That proved Romans and\nGreeks came to Tamil Nadu. Finding Tamil names in Egypt\nproves Tamils also traveled there. Both sides travelled\nto each other’s lands. Ancient Tamil hubs were like\nmodern global trade centers. Despite limited transport,\nmobility and trade were strong. This shows Tamil Nadu was\nhighly advanced in that era. Sixth, South India\nwas integrated into the Roman'),
#  Document(metadata={}, page_content="modern global trade centers. Despite limited transport,\nmobility and trade were strong. This shows Tamil Nadu was\nhighly advanced in that era. Sixth, South India\nwas integrated into the Roman\ncosmopolitan world. A massive cultural exchange\nexisted between these regions. People traveled,\nsettled, and shared ideas. Seventh, Tamil presence\nwasn't limited to ports. They didn't just stay\nat the water's edge. Traveling 600 kilometers inland\nsuggests deeper settlement. Tamils likely lived\nalong those routes. Tamil identity\nwas visible there. This implies\nbroader integration. Eighth, they were driven\nby religious curiosity. Why would Sikai Kotran\nwant to see these tombs? If I visit London, I make\nit a point to see Scotland. I want to see the scenery\nand historical landmarks. I visit sites like Waterloo\nout of historical interest. Such journeys reflect\ncuriosity about art and heritage. Sikai Kotran traveled 600 kilometers\nout of that same curiosity. They wanted to learn how"),
#  Document(metadata={}, page_content="out of historical interest. Such journeys reflect\ncuriosity about art and heritage. Sikai Kotran traveled 600 kilometers\nout of that same curiosity. They wanted to learn how\nthe Pharaohs were buried. It's rare for one culture to\nexplore another so deeply. Usually, traders just\nfocus on the business. But these Tamils were\ntrue global explorers. Kiran, Kotran, and Koppan\nwere pioneers of their time. They ventured out\nto see the world. It's a fascinating history. Ninth, in the Sangam era, Tamils were not\nisolated from the world. They were part of a\nglobalized community. They practiced\nearly globalization. Trade, diplomacy, and exchange\nwere active 2,000 years ago. People traveled, learned,\nand shared culture. They brought global culture\nhome and shared theirs abroad. They lived proudly with\nidentity, without fear. This knowledge is\nincredibly valuable. I wanted to share\nthis story with you. It might seem small, but finding these names\nis historically profound. That's the beauty"),
#  Document(metadata={}, page_content="identity, without fear. This knowledge is\nincredibly valuable. I wanted to share\nthis story with you. It might seem small, but finding these names\nis historically profound. That's the beauty\nof archaeology. One small finding can\nmap out an entire era. I appreciate the government's\neffort in supporting this. We must acknowledge progress as we critique mistakes. Research must continue\nacross all administrations. We need to keep\nuncovering the past. Development means\nresearch, not just preservation. We must actively seek\nout what is still hidden. That strengthens\nclaims of Tamil antiquity. More evidence is needed to prove Tamil was\nthe first language. It's great to see these\nfindings coming to light. Share this with\nfriends worldwide who are interested\nin Tamil history. Sikai Kotran was a\npioneer of global travel. Share this video if\nyou found it interesting. I will see you tomorrow. Love you all! Take care, bye! Cheers, MG's!")]

# %%
len(chunks)
# Out:
# 12

# %% [markdown]
# ## Embedding generation and storing in vectore store

# %%
import google.generativeai as genai
import os

genai.configure(api_key=os.environ["GEMINI_API_KEY"])

for m in genai.list_models():
    if "embed" in m.name.lower():
        print(m.name, " | ", m.supported_generation_methods)
# Out:
# models/gemini-embedding-001  |  ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']

# %%
embedding = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")
vectorstore = FAISS.from_documents(chunks, embedding)

# %%
vectorstore.index_to_docstore_id
# Out:
# {0: '47b1854c-ed70-4bab-99de-06370245ea2b',
#  1: '4d8b31fa-a642-4efc-ba8e-fbc1db4c48eb',
#  2: '3048880a-7d24-4a38-bebc-5506b04fe650',
#  3: '49aeb334-17ef-4cc4-b759-c4341870ec71',
#  4: 'd03c4e5a-d4f4-4a22-b755-191d7f047414',
#  5: '1e75abc3-36a6-4011-826d-337a40f3b5f0',
#  6: 'e4291a0a-50e6-4a8e-86ef-1bfd3f51c777',
#  7: '171ae5b8-f325-4d93-8f14-584e90945b18',
#  8: 'd8f883cf-7738-4fea-812e-52cc10e88701',
#  9: '60307b38-d2d4-4038-91a3-a16b76edf193',
#  10: '771f3d89-5df4-4112-9e01-ff273eef0efb',
#  11: '95d55624-77c7-4f80-9ee6-95532d61f7d6'}

# %%
vectorstore.get_by_ids(['47b1854c-ed70-4bab-99de-06370245ea2b'])
# Out:
# [Document(id='47b1854c-ed70-4bab-99de-06370245ea2b', metadata={}, page_content="[Intro music plays] Hello, everyone!\nI’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major\nrecent discovery. A three-day conference\nwas recently held. Scientists and\narchaeologists from Switzerland and\nFrance participated. They presented evidence\nof Tamil presence. Not many people are\naware of this breakthrough. Tamil names were discovered\nin Egypt's Valley of the Kings. This is the sacred burial\nsite of Egyptian Pharaohs. Great kings were buried there\nwith gold and precious gems. Tamil names were\nfound in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this\nvideo will give you goosebumps. We often discuss\nglobalization today. We talk about international\ntrade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual")]

# %% [markdown]
# ## Retrival

# %%
retriver = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 2})

# %%
retriver
# Out:
# VectorStoreRetriever(tags=['FAISS', 'GoogleGenerativeAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x78cd43bd1580>, search_kwargs={'k': 2})

# %%
retriver.invoke("Where Tamil words were carved")
# Out:
# [Document(id='47b1854c-ed70-4bab-99de-06370245ea2b', metadata={}, page_content="[Intro music plays] Hello, everyone!\nI’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major\nrecent discovery. A three-day conference\nwas recently held. Scientists and\narchaeologists from Switzerland and\nFrance participated. They presented evidence\nof Tamil presence. Not many people are\naware of this breakthrough. Tamil names were discovered\nin Egypt's Valley of the Kings. This is the sacred burial\nsite of Egyptian Pharaohs. Great kings were buried there\nwith gold and precious gems. Tamil names were\nfound in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this\nvideo will give you goosebumps. We often discuss\nglobalization today. We talk about international\ntrade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual"),
#  Document(id='3048880a-7d24-4a38-bebc-5506b04fe650', metadata={}, page_content="alongside global events. Join us to stay informed. Now, let's look at\nwhat was discovered. We must credit the\nTamil Nadu government. They played a vital\nrole in this research. The government organized\nthe Tamil Epigraphy Conference. It was held in Chennai\nfrom February 11th to 14th. The focus was on ancient\nTamil scripts and research. Experts from China, Africa, Europe, and America attended. These are world-renowned\nscholars of the Tamil language. They study archaeological\nsites worldwide. This conference united experts\nresearching Tamil inscriptions. Professor Ingo and Professor\nCharlotte presented their findings. They produced a\ndetailed research paper. They identified 30 inscriptions\ninside royal tombs in Egypt. These are located in\nthe Valley of the Kings. The Valley of the\nKings is in Egypt. It dates back\nthousands of years, long before the era of Jesus. The pyramids were built as royal\nburial sites around 5,000 years ago. Kings were mummified and")]

# %% [markdown]
# ## Agumentation

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.3)

# %%
prompt = PromptTemplate(

    template =
    """
    You are a helpful assistant. answer only from provided transcript context. if the content is insufficient, just say you dont known
    {context}
    Question: {question}
    """,

    input_variables=["context", "question"]
)

# %%
user_question = "is the language Tamil is discussed in this video? if yes then what was discussed"
retrived_docs = retriver.invoke(user_question)

# %%
retrived_docs
# Out:
# [Document(id='47b1854c-ed70-4bab-99de-06370245ea2b', metadata={}, page_content="[Intro music plays] Hello, everyone!\nI’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major\nrecent discovery. A three-day conference\nwas recently held. Scientists and\narchaeologists from Switzerland and\nFrance participated. They presented evidence\nof Tamil presence. Not many people are\naware of this breakthrough. Tamil names were discovered\nin Egypt's Valley of the Kings. This is the sacred burial\nsite of Egyptian Pharaohs. Great kings were buried there\nwith gold and precious gems. Tamil names were\nfound in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this\nvideo will give you goosebumps. We often discuss\nglobalization today. We talk about international\ntrade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual"),
#  Document(id='95d55624-77c7-4f80-9ee6-95532d61f7d6', metadata={}, page_content="identity, without fear. This knowledge is\nincredibly valuable. I wanted to share\nthis story with you. It might seem small, but finding these names\nis historically profound. That's the beauty\nof archaeology. One small finding can\nmap out an entire era. I appreciate the government's\neffort in supporting this. We must acknowledge progress as we critique mistakes. Research must continue\nacross all administrations. We need to keep\nuncovering the past. Development means\nresearch, not just preservation. We must actively seek\nout what is still hidden. That strengthens\nclaims of Tamil antiquity. More evidence is needed to prove Tamil was\nthe first language. It's great to see these\nfindings coming to light. Share this with\nfriends worldwide who are interested\nin Tamil history. Sikai Kotran was a\npioneer of global travel. Share this video if\nyou found it interesting. I will see you tomorrow. Love you all! Take care, bye! Cheers, MG's!")]

# %%
context_text = "\n\n".join(doc.page_content for doc in retrived_docs)
context_text
# Out:
# "[Intro music plays] Hello, everyone!\nI’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major\nrecent discovery. A three-day conference\nwas recently held. Scientists and\narchaeologists from Switzerland and\nFrance participated. They presented evidence\nof Tamil presence. Not many people are\naware of this breakthrough. Tamil names were discovered\nin Egypt's Valley of the Kings. This is the sacred burial\nsite of Egyptian Pharaohs. Great kings were buried there\nwith gold and precious gems. Tamil names were\nfound in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this\nvideo will give you goosebumps. We often discuss\nglobalization today. We talk about international\ntrade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual\n\nidentity, without fear. This knowledge is\nincredibly valuable. I wanted to share\nthis story with you. It might seem small, but finding these names\nis historically profound. That's the beauty\nof archaeology. One small finding can\nmap out an entire era. I appreciate the government's\neffort in supporting this. We must acknowledge progress as we critique mistakes. Research must continue\nacross all administrations. We need to keep\nuncovering the past. Development means\nresearch, not just preservation. We must actively seek\nout what is still hidden. That strengthens\nclaims of Tamil antiquity. More evidence is needed to prove Tamil was\nthe first language. It's great to see these\nfindings coming to light. Share this with\nfriends worldwide who are interested\nin Tamil history. Sikai Kotran was a\npioneer of global travel. Share this video if\nyou found it interesting. I will see you tomorrow. Love you all! Take care, bye! Cheers, MG's!"

# %%
final_prompt = prompt.invoke({"context":context_text, "question":user_question})
final_prompt
# Out:
# StringPromptValue(text="\n    You are a helpful assistant. answer only from provided transcript context. if the content is insufficient, just say you dont known\n    [Intro music plays] Hello, everyone!\nI’m Madan Gowri. Hello, my dear MG squad! Would you believe Tamil words were carved in Egypt’s pyramids? This is a major\nrecent discovery. A three-day conference\nwas recently held. Scientists and\narchaeologists from Switzerland and\nFrance participated. They presented evidence\nof Tamil presence. Not many people are\naware of this breakthrough. Tamil names were discovered\nin Egypt's Valley of the Kings. This is the sacred burial\nsite of Egyptian Pharaohs. Great kings were buried there\nwith gold and precious gems. Tamil names were\nfound in this very location. I will explain those names. But first, watch this. For Tamils worldwide, this\nvideo will give you goosebumps. We often discuss\nglobalization today. We talk about international\ntrade and connectivity. We also discuss\nissues that arise when leaders like\nTrump come to power. But 2,000 years ago, Tamils were already practicing\nglobalization. Today, we have actual\n\nidentity, without fear. This knowledge is\nincredibly valuable. I wanted to share\nthis story with you. It might seem small, but finding these names\nis historically profound. That's the beauty\nof archaeology. One small finding can\nmap out an entire era. I appreciate the government's\neffort in supporting this. We must acknowledge progress as we critique mistakes. Research must continue\nacross all administrations. We need to keep\nuncovering the past. Development means\nresearch, not just preservation. We must actively seek\nout what is still hidden. That strengthens\nclaims of Tamil antiquity. More evidence is needed to prove Tamil was\nthe first language. It's great to see these\nfindings coming to light. Share this with\nfriends worldwide who are interested\nin Tamil history. Sikai Kotran was a\npioneer of global travel. Share this video if\nyou found it interesting. I will see you tomorrow. Love you all! Take care, bye! Cheers, MG's!\n    Question: is the language Tamil is discussed in this video? if yes then what was discussed\n    ")

# %% [markdown]
# ## Genaration

# %%
answer = llm.invoke(final_prompt)

# %%
print(answer.content)
# Out:
# Yes, the language Tamil is discussed in this video.
#
# It was discussed that:
# *   Tamil words were carved in Egypt's pyramids.
# *   Scientists and archaeologists from Switzerland and France presented evidence of Tamil presence.
# *   Tamil names were discovered in Egypt's Valley of the Kings, the sacred burial site of Egyptian Pharaohs.
# *   Tamils were practicing globalization 2,000 years ago.
# *   More evidence is needed to prove Tamil was the first language.

# %% [markdown]
# ## Do this same with Chain method

# %%
# !pip install -q langchain

# %%
from langchain.prompts import PromptTemplate
from langchain.llms import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain.chains import LLMChain
